# %% [markdown]
# <div style="text-align: center; background: linear-gradient(135deg, #1a237e 0%, #283593 50%, #303f9f 100%); color: white; padding: 35px; border-radius: 12px; margin: 25px 0; font-family: 'Segoe UI', 'Arial', sans-serif; font-weight: 700; font-size: 1.9em; box-shadow: 0 6px 25px rgba(0,0,0,0.05); border-bottom: 4px solid #5c6bc0;">
# Predictive Analytics Using Linear Regression for Machine Learning Applications
# </div>
#
# <hr style="border: none; height: 2px; background: linear-gradient(to right, transparent, #5c6bc0, transparent); margin: 30px auto; width: 75%;">
#
# <div style="background: #f8f9fa; color: #2c3e50; padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 5px solid #5c6bc0; border-right: 5px solid #5c6bc0;box-shadow: 0 4px 15px rgba(0,0,0,0.08);">
# <h3 style="color: #1a237e; margin-top: 0; text-align: center; font-weight: 600; font-size: 1.6em; margin-bottom: 15px;">
# LEARNING OBJECTIVES
# </h3>
# <p style="color: #2c3e50; font-size: 1.15em; line-height: 1.7; text-align: justify; margin: 0 40px 5px; font-weight: 500;"> By the end of this activity, you will be able to:</p>
#   <ul style="font-size: 1.1em; line-height: 1.7; color: #2c3e50; margin: 0 60px 25px; font-weight: 500;">
#     <li>Load and explore a housing dataset using pandas</li>
#     <li>Select appropriate features for predictive modeling</li>
#     <li>Prepare data for machine learning by separating features (X) and target (y)</li>
#     <li>Train a Decision Tree Regressor model using <code>scikit-learn</code></li>
#     <li>Train a Linear Regression model using <code>scikit-learn</code></li>
#     <li>Make predictions with trained models</li>
#     <li>Evaluate model performance using R² score and interpret the results</li>
#     <li>Compare different regression algorithms for the same prediction task</li>
#   </ul>
#
#   <p style="color: #2c3e50; font-size: 1.15em; line-height: 1.7; text-align: justify; margin: 0 40px 25px; font-weight: 500;">
#     <strong>Dataset:</strong>
#     You are given the file <code>housing_train.csv</code>.
#     <br><br>
#     This dataset contains housing price information with features including:
#   </p>
#
# <ul style="font-size: 1.1em; line-height: 1.7; color: #2c3e50; margin: 0 60px 25px; font-weight: 500;">
#   <li><strong>LotArea:</strong> Lot size in square feet</li>
#   <li><strong>YearBuilt:</strong> Original construction year</li>
#   <li><strong>1stFlrSF:</strong> First Floor square feet</li>
#   <li><strong>2ndFlrSF:</strong> Second floor square feet</li>
#   <li><strong>FullBath:</strong> Full bathrooms above grade</li>
#   <li><strong>BedroomAbvGr:</strong> Bedrooms above grade</li>
#   <li><strong>TotRmsAbvGrd:</strong> Total rooms above grade</li>
#   <li><strong>SalePrice:</strong> The property's sale price (target variable)</li>
# </ul>
#
# <div style="background: white; padding: 25px; border-radius: 8px; margin: 20px 0; border: 1px solid #e0e0e0;">
# <div style="display: flex; justify-content: space-evenly; align-items: center; text-align: center; width: 100%;">
#
# <div style="width: 33%">
# <strong style="color: #5c6bc0; display: block; margin-bottom: 8px; font-size: 1.1em;">Data Analyst</strong>
# <span style="color: #1a237e; font-weight: 600; font-size: 1.1em;">Jomel Tomeo</span>
# </div>
#
# <div style="width: 33%">
# <strong style="color: #5c6bc0; display: block; margin-bottom: 8px; font-size: 1.1em;">Report Date</strong>
# <span style="color: #1a237e; font-weight: 600; font-size: 1.1em;">October 28, 2025</span>
# </div>
#
# <div style="width: 33%">
# <strong style="color: #5c6bc0; display: block; margin-bottom: 8px; font-size: 1.1em;">Dataset</strong>
# <span style="color: #1a237e; font-weight: 600; font-size: 1.1em;">Housing Prices</span>
# </div>
# </div>
# </div>
#
# <div style="text-align: center; margin-top: 30px;">
# <span style="background: #5c6bc0; color: white; padding: 8px 20px; border-radius: 20px; font-weight: 600; font-size: 0.9em;">
#   <strong>Goal:</strong> Predict housing prices using Decision Tree and Linear Regression models.
# </span>
# </div>
#
# </div>

# %% [markdown]
# <h3 style="text-align: center; background: #3f51b5; color: white; padding: 18px; border-radius: 8px; margin: 25px 0; font-family: 'Segoe UI', sans-serif; font-weight: 600; font-size: 1.4em;">
# STEP 1
# </h3>

# %% [markdown]
# ## Specify Prediction Target
# Select the target variable, which corresponds to the sales price. Save this to a new variable called <b>y</b>. <br>
#
# You'll need to print a list of the columns to find the name of the column you need.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Load dataset (replace with your housing dataset file path)
housing = pd.read_csv("datasets\\housing_train.csv")

y = housing['SalePrice']

# %% [markdown]
# <h3 style="text-align: center; background: #3f51b5; color: white; padding: 18px; border-radius: 8px; margin: 25px 0; font-family: 'Segoe UI', sans-serif; font-weight: 600; font-size: 1.4em;">
# STEP 2
# </h3>

# %% [markdown]
# ## Create X
# Now you will create a DataFrame called X holding the predictive features.
#
# Since you want only some columns from the original data, you'll first create a list with the names of the columns you want in X.
#
# You'll use just the following columns in the list (you can copy and paste the whole list to save some typing, though you'll still need to add quotes):
# - LotArea
# - YearBuilt
# - 1stFlrSF
# - 2ndFlrSF
# - FullBath
# - BedroomAbvGr
# - TotRmsAbvGrd
# After you've created that list of features, use it to create the DataFrame that you'll use to fit the model.

# %%
# Select columns related to making prediction values 
# Feature selection / select columns 

features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr',  'TotRmsAbvGrd']

X = housing[features]

# %%
X
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0        8450       2003       856       854         2             3
# 1        9600       1976      1262         0         2             3
# 2       11250       2001       920       866         2             3
# 3        9550       1915       961       756         1             3
# 4       14260       2000      1145      1053         2             4
# ...       ...        ...       ...       ...       ...           ...
# 1455     7917       1999       953       694         2             3
# 1456    13175       1978      2073         0         2             3
# 1457     9042       1941      1188      1152         2             4
# 1458     9717       1950      1078         0         1             2
# 1459     9937       1965      1256         0         1             3
#
#       TotRmsAbvGrd
# 0                8
# 1                6
# 2                6
# 3                7
# 4                9
# ...            ...
# 1455             7
# 1456             7
# 1457             9
# 1458             5
# 1459             6
#
# [1460 rows x 7 columns]

# %% [markdown]
# When you've updated the starter code, <b> check()  </b> will tell you whether your code is correct.
# You need to update the code that creates variable <b>X</b>

# %% [markdown]
# ### Review Data
# Before building a model, take a quick look at X to verify it looks sensible.

# %% [markdown]
# <h3 style="text-align: center; background: #3f51b5; color: white; padding: 18px; border-radius: 8px; margin: 25px 0; font-family: 'Segoe UI', sans-serif; font-weight: 600; font-size: 1.4em;">
# STEP 3
# </h3>

# %% [markdown]
# ## Specify and Fit Model¶
#
# - Create a DecisionTreeRegressor and save it iowa_model. Ensure you've done the relevant import from sklearn to run this command.
#
# Then fit the model you just created using the data in X and y that you saved above.

# %% [markdown]
# <hr>
# <strong>What is a Decision Tree Regressor </strong>
# <p>A decision tree regressor is a machine learning model that uses a tree-like structure to predict a continuous target variable . It works by recursively partitioning the data into smaller and smaller subsets based on the features, ultimately fitting a simple model (like the mean or median of the target variable) to each subset</p>
# <img src= 'https://miro.medium.com/1*62Am0QdlxCq5Vmt5siR-7Q.png' />

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model
my_model = DecisionTreeRegressor()

# Fit model
my_model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# <h3 style="text-align: center; background: #3f51b5; color: white; padding: 18px; border-radius: 8px; margin: 25px 0; font-family: 'Segoe UI', sans-serif; font-weight: 600; font-size: 1.4em;">
# STEP 4
# </h3>

# %% [markdown]
# ## Make Predictions
# Make predictions with the model's predict command using X as the data. Save the results to a variable called predictions.

# %%
# Make predictions
predictions = my_model.predict(X)

# %%
predictions
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.],
#       shape=(1460,))

# %% [markdown]
# <h3 style="text-align: center; background: #3f51b5; color: white; padding: 18px; border-radius: 8px; margin: 25px 0; font-family: 'Segoe UI', sans-serif; font-weight: 600; font-size: 1.4em;">
# STEP 5
# </h3>

# %% [markdown]
# ## Testing the Accuracy of Prediction
# Since the sales prices are continuing data or ordinal data.

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, predictions)
print("R² Score:", r2)
print(f"The model variation is at {r2:.1%}")
# Out:
# R² Score: 0.9999346278363472
# The model variation is at 100.0%

# %% [markdown]
# <h3 style="text-align: center; background: #3f51b5; color: white; padding: 18px; border-radius: 8px; margin: 25px 0; font-family: 'Segoe UI', sans-serif; font-weight: 600; font-size: 1.4em;">
# PREDICTION USING LINEAR REGRESSION
# </h3>

# %%
from sklearn.linear_model import LinearRegression

# %%
my_model = LinearRegression()
my_model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = my_model.predict(X)
predictions
# Out:
# array([219164.64359536, 161876.1612803 , 217670.6719971 , ...,
#        215189.55784088, 131337.00066566, 152147.85672781], shape=(1460,))

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, predictions)
print(f"R² Score:, {r2:.1%}")
# Out:
# R² Score:, 70.5%

# %% [markdown]
# <div style="font-family: Arial, sans-serif; font-size: 14px; color: #222; line-height: 1.6; margin-top: 40px; text-align: center;">
#   <div style="margin-bottom: 15px;">
#     <p style="margin: 5px 0; text-align: center;"><strong>Data Analysis by:</strong> Jomel Tomeo</p>
#     <p style="margin: 5px 0; text-align: center;"><strong>Institution/Organization:</strong> Dalubhasaan ng Lungsod ng Lucena</p>
#     <p style="margin: 5px 0; text-align: center;"><strong>Date:</strong> October 28, 2025</p>
#   </div>
#
#   <div style="width: 50%; margin: 20px auto; border-top: 1px solid #aaa;"></div>
#
#   <div style="font-size: 12px; color: #666; margin-top: 20px; max-width: 600px; margin-left: auto; margin-right: auto; text-align: center;">
#     © 2025 All rights reserved. This analysis is prepared exclusively for academic and professional purposes.
#     No part of this work may be reproduced, distributed, or transmitted without prior permission.
#   </div>
# </div>
